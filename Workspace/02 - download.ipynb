# %% [markdown]
# ## Download de arquivos
# Notebook criado com o intuito de criar os volumes necessários para upload dos dados a serem utilizados pelo modelo. Nesse caso, para fins de organização, serão criados dois volumes, um com os dadosdos estados e outro para subir os dados do resultado do saeb.
#
# Os arquivos utilizados tiveram seu upload feito de forma manual por dentro dos volumes criados

# %%
# %sql
USE CATALOG 'mvp-eng-dados-puc-rio';
USE SCHEMA staging;

-- Codigo com objetivo de informar onde serão criados os volumes, no catalogo e schema informados
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE VOLUME dados_saeb

--criação do volume para os dados do exame saeb. Upload dos dados feito de forma manual com um arquivo csv
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE VOLUME dados_estados

--criação do volume para os dados socioeconômicos dos estados. Upload dos dados feito de forma manual com um arquivo excel
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
